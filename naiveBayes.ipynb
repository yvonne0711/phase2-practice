# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv('food_data.csv')  # load our data
data
# Out:
#            Food  Calories  Calories from Fat  Total Fat  Total Fat.1  Sodium  \
# 0     Asparagus        20                  0        0.0            0       0
# 1   Bell Pepper        25                  0        0.0            0      40
# 2      Broccoli        45                  0        0.5            1      80
# 3        Carrot        30                  0        0.0            0      60
# 4   Cauliflower        25                  0        0.0            0      30
# ..          ...       ...                ...        ...          ...     ...
# 56     Scallops       140                 10        1.0            2     310
# 57       Shrimp       100                 10        1.5            2     240
# 58    Swordfish       120                 50        6.0            9     100
# 59      Tilapia       110                 20        2.5            4      30
# 60         Tuna       130                 15        1.5            2      40
#
#     Sodium.1  Potassium  Potassium.1  Total Carbo-hydrate  \
# 0          0        230            7                    4
# 1          2        220            6                    6
# 2          3        460           13                    8
# 3          3        250            7                    7
# 4          1        270            8                    5
# ..       ...        ...          ...                  ...
# 56        13        430           12                    5
# 57        10        220            6                    0
# 58         4        310            9                    0
# 59         1        360           10                    0
# 60         2        480           14                    0
#
#     Total Carbo-hydrate.1  Protein  Vitamin A  Vitamin C  Calcium  Iron  \
# 0                       1        2         10         15        2     2
# 1                       2        1          4        190        2     4
# 2                       3        4          6        220        6     6
# 3                       2        1        110         10        2     2
# 4                       2        2          0        100        2     2
# ..                    ...      ...        ...        ...      ...   ...
# 56                      2       27          2          0        4    14
# 57                      0       21          4          4        6    10
# 58                      0       16          2          2        0     6
# 59                      0       22          0          2        0     2
# 60                      0       26          2          2        2     4
#
#      Food Type
# 0   Vegetables
# 1   Vegetables
# 2   Vegetables
# 3   Vegetables
# 4   Vegetables
# ..         ...
# 56     Seafood
# 57     Seafood
# 58     Seafood
# 59     Seafood
# 60     Seafood
#
# [61 rows x 17 columns]

# %%
data.index = data.iloc[:,0] # Name each row of the food column as food name for reference
data_to_use = data.iloc[:,3:15] #columns 3 to 15
data_to_target = data.iloc[:,16] #last column
data.index
# Out:
# Index(['Asparagus', 'Bell Pepper', 'Broccoli', 'Carrot', 'Cauliflower',
#        'Celery', 'Cucumber', 'Green (Snap) Beans', 'Green Cabbage',
#        'Green Onion', 'Iceberg Lettuce', 'Leaf Lettuce', 'Mushrooms', 'Onion',
#        'Potato', 'Radishes', 'Summer Squash', 'Sweet Corn', 'Sweet Potato',
#        'Tomato', 'Apple', 'Avocado', 'Banana', 'Cantaloupe', 'Grapefruit',
#        'Grapes', 'Honeydew Melon', 'Kiwifruit', 'Lemon', 'Lime', 'Nectarine',
#        'Orange', 'Peach', 'Pear', 'Pineapple', 'Plums', 'Strawberries',
#        'Sweet Cherries', 'Tangerine', 'Watermelon', 'Blue Crab', 'Catfish',
#        'Clams', 'Cod', 'Flounder/Sole', 'Haddock', 'Halibut', 'Lobster',
#        'Ocean Perch', 'Orange Roughy', 'Oysters', 'Pollock', 'Rainbow Trout',
#        'Rockfish', 'Salmon, Atlantic/Coho/Sockeye /Chinook', 'Salmon, Pink',
#        'Scallops', 'Shrimp', 'Swordfish', 'Tilapia', 'Tuna'],
#       dtype='object', name='Food')

# %%
data_to_use
# Out:
#              Total Fat  Total Fat.1  Sodium  Sodium.1  Potassium  Potassium.1  \
# Food
# Asparagus          0.0            0       0         0        230            7
# Bell Pepper        0.0            0      40         2        220            6
# Broccoli           0.5            1      80         3        460           13
# Carrot             0.0            0      60         3        250            7
# Cauliflower        0.0            0      30         1        270            8
# ...                ...          ...     ...       ...        ...          ...
# Scallops           1.0            2     310        13        430           12
# Shrimp             1.5            2     240        10        220            6
# Swordfish          6.0            9     100         4        310            9
# Tilapia            2.5            4      30         1        360           10
# Tuna               1.5            2      40         2        480           14
#
#              Total Carbo-hydrate  Total Carbo-hydrate.1  Protein  Vitamin A  \
# Food
# Asparagus                      4                      1        2         10
# Bell Pepper                    6                      2        1          4
# Broccoli                       8                      3        4          6
# Carrot                         7                      2        1        110
# Cauliflower                    5                      2        2          0
# ...                          ...                    ...      ...        ...
# Scallops                       5                      2       27          2
# Shrimp                         0                      0       21          4
# Swordfish                      0                      0       16          2
# Tilapia                        0                      0       22          0
# Tuna                           0                      0       26          2
#
#              Vitamin C  Calcium
# Food
# Asparagus           15        2
# Bell Pepper        190        2
# Broccoli           220        6
# Carrot              10        2
# Cauliflower        100        2
# ...                ...      ...
# Scallops             0        4
# Shrimp               4        6
# Swordfish            2        0
# Tilapia              2        0
# Tuna                 2        2
#
# [61 rows x 12 columns]

# %%
data_to_target
# Out:
# Food
# Asparagus      Vegetables
# Bell Pepper    Vegetables
# Broccoli       Vegetables
# Carrot         Vegetables
# Cauliflower    Vegetables
#                   ...
# Scallops          Seafood
# Shrimp            Seafood
# Swordfish         Seafood
# Tilapia           Seafood
# Tuna              Seafood
# Name: Food Type, Length: 61, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=0.3, random_state=21) # 70% training, 30% test

# %%
gaussian_model = GaussianNB() # Gaussian model

# %%
gaussian_model.fit(X_train, y_train) # Training the model
# Out:
# GaussianNB()

# %%
prediction = gaussian_model.predict(X_test) # Predict the response for food
prediction
# Out:
# array(['Vegetables', 'Seafood', 'Fruits', 'Fruits', 'Fruits',
#        'Vegetables', 'Fruits', 'Vegetables', 'Vegetables', 'Seafood',
#        'Seafood', 'Vegetables', 'Vegetables', 'Fruits', 'Vegetables',
#        'Fruits', 'Seafood', 'Vegetables', 'Vegetables'], dtype='<U10')

# %%
result = {'food_type':y_test, 'pred':prediction}
result_df = pd.DataFrame(result)
result
# Out:
# {'food_type': Food
#  Cantaloupe                Fruits
#  Oysters                  Seafood
#  Sweet Corn            Vegetables
#  Banana                    Fruits
#  Broccoli              Vegetables
#  Tomato                Vegetables
#  Orange                    Fruits
#  Green (Snap) Beans    Vegetables
#  Lemon                     Fruits
#  Pollock                  Seafood
#  Avocado                   Fruits
#  Grapefruit                Fruits
#  Honeydew Melon            Fruits
#  Peach                     Fruits
#  Potato                Vegetables
#  Nectarine                 Fruits
#  Shrimp                   Seafood
#  Carrot                Vegetables
#  Leaf Lettuce          Vegetables
#  Name: Food Type, dtype: object,
#  'pred': array(['Vegetables', 'Seafood', 'Fruits', 'Fruits', 'Fruits',
#         'Vegetables', 'Fruits', 'Vegetables', 'Vegetables', 'Seafood',
#         'Seafood', 'Vegetables', 'Vegetables', 'Fruits', 'Vegetables',
#         'Fruits', 'Seafood', 'Vegetables', 'Vegetables'], dtype='<U10')}

# %%
result_df
# Out:
#                      food_type        pred
# Food
# Cantaloupe              Fruits  Vegetables
# Oysters                Seafood     Seafood
# Sweet Corn          Vegetables      Fruits
# Banana                  Fruits      Fruits
# Broccoli            Vegetables      Fruits
# Tomato              Vegetables  Vegetables
# Orange                  Fruits      Fruits
# Green (Snap) Beans  Vegetables  Vegetables
# Lemon                   Fruits  Vegetables
# Pollock                Seafood     Seafood
# Avocado                 Fruits     Seafood
# Grapefruit              Fruits  Vegetables
# Honeydew Melon          Fruits  Vegetables
# Peach                   Fruits      Fruits
# Potato              Vegetables  Vegetables
# Nectarine               Fruits      Fruits
# Shrimp                 Seafood     Seafood
# Carrot              Vegetables  Vegetables
# Leaf Lettuce        Vegetables  Vegetables

# %%
print("Accuracy:", metrics.accuracy_score(y_test, prediction)) # Checking NB accuracy
# Out:
# Accuracy: 0.631578947368421
